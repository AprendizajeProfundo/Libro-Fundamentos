# %% [markdown]
# # UMAP
# **Unifold Manifold Approximation and Projection**
#
#
# ![image.png](data:image/png;base64,...) [Fuente: How exactly UMAP works](https://towardsdatascience.com/how-exactly-umap-works-13e3040e1668)

# %% [markdown]
# # Referencias
#
#
#
# 1.   [McInnes, L, Healy, J, UMAP: Uniform Manifold Approximation and Projection for Dimension Reduction, ArXiv e-prints 1802.03426, 2018](https://umap-learn.readthedocs.io/en/latest/api.html)
# 2.   [t-SNE](https://www.youtube.com/watch?v=NEaUSP4YerM)
# 3.   [UMAP Dimension Reduction, Main ideas!](https://www.youtube.com/watch?v=eN0wFzBA4Sc&t=200s)
#
# 4.   [PCA main ideas](https://www.youtube.com/watch?v=HMOI_lkzW08&t=130s)
# 5.   [How exactly UMAP works](https://towardsdatascience.com/how-exactly-umap-works-13e3040e1668)
# 6. [API design for machine learning software: experiences from the scikit-learn project](https://scikit-learn.org/stable/about.html#citing-scikit-learn) Buitinck et al., 2013
# 7. [Introduction to Dimensionality Reduction Technique](https://www.javatpoint.com/dimensionality-reduction-technique)
# 8. [UMAP Dimensionality Reduction — An Incredibly Robust Machine Learning Algorithm](https://towardsdatascience.com/umap-dimensionality-reduction-an-incredibly-robust-machine-learning-algorithm-b5acb01de568)
# 9. [UMAP for t-SNE](https://jlmelville.github.io/uwot/umap-for-tsne.html#UMAP_(at_last))

# %% [markdown]
# # Profesor
#
# 1.   Alvaro Montenegro, PhD, ammontenegrod@unal.edu.co

# %% [markdown]
# # Autores
#
#
# 1.   Nicolle Quintero, nquinterom@unal.edu.co
# 2.   Paula Garcia, pagarcian@unal.edu.co

# %% [markdown]
# # Introducción

# %% [markdown]
# Desde cómo cazar un mamut hasta tomar la decisión de invertir o no en la bolsa, la planeación ha acompañado a la humanidad en su crecimiento y desarrollo. El ser humano planea y ejecuta esperando un resultado igual a lo que ya había pensado, o al menos con un margen de error muy bajo. y allí, es donde el aprendizaje toma partida. Si. “No fracasé, sólo descubrí 999 maneras de cómo no hacer una bombilla”-Thomas Edison.

# %% [markdown]
# ![image.png](data:image/png;base64,...) Imagen 0. Fuente: Imagenes de Canva

# %% [markdown]
# El hombre aprende de sus errores, y los toma en cuenta para seguir planeando y esperando tener un control más certero sobre su futuro.
#
# Al día de hoy, sabemos que la digitalización ha cambiado nuestra forma de hacer las cosas, reduce tiempos y distancias, nos permite compartir experiencias y conocimientos,etc. Pero no siempre fue así.
#
# Para cualquier empresa, los registros de sus ventas, inventario y en general de su dinámica se hacían manualmente (Sí, a papel y lápiz), y aún así, usaban esa información para hacer estadística descriptiva y lograr tomar decisiones que cumplieran con sus objetivos comerciales. Ahora, en esta revolución digital, existen muchísimas herramientas, no solo de recolección de datos, sino de almacenamiento y procesamiento. La estadística, ahora va más allá de sacar conclusiones sobre el rendimiento de un mes de una empresa, sino que puede hasta lograr predecir su éxito dando información sobre el comportamiento de clientes, áreas que necesitan más trabajo, etc.

# %% [markdown]
# Pero entramos en un conflicto cuando tenemos una gran cantidad de variables. Supongamos que tenemos toda la información de una empresa en una base de datos, y visualizar los datos siempre es una buena idea para comenzar a interpretar su posible relación, datos no normales (datos atípicos), agrupaciones, etc. Pero, ¿Cómo ubico tanta información en un dibujo? Si tenemos dos variables, por ejemplo peso y estatura de una persona, en un plano con dos ejes, uno horizontal (X) y otro vertical (Y), puedo ubicar la información sin mucho problema. Incluso, con nuevas herramientas podemos hacer un dibujo en tres dimensiones (3D) para tres variables en una pantalla de dos dimensiones.¿Cómo se dibuja en cuatro, cinco, seis o incluso 100 dimensiones? Simplemente no es posible.

# %% [markdown]
# Para eso, el ser humano ha desarrollado técnicas de reducción de dimensionalidad, cada vez más avanzadas, eficientes y refinadas (Incluso en el año 2022) para que al momento de reducir la cantidad de variables, o dimensionalidad, se pierda la menor cantidad de información posible para el analisis de estas

# %% [markdown]
# El conjunto de técnicas que se pueden emplear para la reducción de dimensiones se puede dividir en dos formas importantes; se pueden separar en técnicas que se aplican al aprendizaje supervisado o no supervisado y en técnicas que implican la selección de características o la extracción de características

# %% [markdown]
# ![image.png](data:image/png;base64,...)Imagen 1 [Fuente:Introduction to Dimensionality Reduction Technique](https://www.javatpoint.com/dimensionality-reduction-technique)

# %% [markdown]
# # Nota histórica

# %% [markdown]
# En este documento nos vamos a centrar en un método llamado UMAP por sus siglas en inglés Unfold Manifold Approximation and Projection desarrollado aproximadamente en el año 2018. Pero para eso, vamos hacer un recorrido histórico de técnicas anteriores de donde salió UMAP. Como los ancestros que dieron origen a una nueva forma de sacar mayor provecho a los datos de grandes cantidades de variables.

# %% [markdown]
# ### **PCA( Principal Component Analysis)**

# %% [markdown]
#  Comenzamos con esta técnica, muy usada igualmente en la actualidad. (Si ya conoces cómo funciona esta técnica, puedes saltar a la siguiente. De lo contrario, ¡No te preocupes! aquí te vamos a dar un resumen práctico)

# %% [markdown]
# Imaginemos que nos dan información sobre el análisis genético (ADN) de un grupo de  5 perros (ver imagen 2). Normalmente, las razas de perros comparten ciertos genes y de hecho, un perro puede ser clasificado dentro de una raza o no por su registro de raza (el análisis genético).

# %% [markdown]
# ![image.png](data:image/png;base64,...) Imagen 2 Fuente:Autor

# %% [markdown]
# Tomemos la información del perro 1 y perro 2, y hagamos un diagrama de dispersión (imagen 3) que nos permite ver la “cantidad de un gen” en específico para los dos animales. Lo que nos permitiría ver, que por ejemplo, el perro 1 y perro 2 no comparten la misma “intensidad” de cada gen, por lo tanto, podrían ser de razas diferentes.

# %% [markdown]
# ![image.png](data:image/png;base64,...) Imagen 3. Fuente: Autor

# %% [markdown]
# Ahora, miremos el perro 1 y el perro 3 (imagen4). Por nuestro diagrama de dispersión, vemos que están relacionados, sus cantidades en cada uno de los genes son similares, por ende, pueden ser de la misma raza.

# %% [markdown]
# ![image.png](data:image/png;base64,...) imagen 4 Fuente:Autor

# %% [markdown]
# Lo que hace PCA es agrupar la información altamente relacionada y graficarla en un plano de dos dimensiones(Ver imagen5).

# %% [markdown]
# ![image.png](data:image/png;base64,...) Imagen 5. Fuente:Autor

# %% [markdown]
# **Tener en cuenta:** Las diferencias entre los componentes mirando desde cada eje son distintas (Comenzando por orden de importancia con el eje horizontal). Por ejemplo, digamos que usamos PCA y obtuvimos tres razas de perros. Por el diagrama, podemos ver que el grupo azul está a la misma distancia del grupo naranja y del grupo verde. Pero, el grupo azul es “más diferente” del grupo verde, que haciendo la comparación con el grupo naranja

# %% [markdown]
# ### **t-SNE. (T-Distributed Stochastic Neighbor Embedding)**

# %% [markdown]
# Ahora que tenemos la idea de cómo funciona PCA y en general, la reducción de la dimensionalidad y su utilidad (No hay límite si se desea ahondar más en el tema), vamos a ver la técnica t-SNE, desarrollada en 2008 por Van Der Maaten y Hinton. ([Clic aqui para acceder al paper](https://www.jmlr.org/papers/volume9/vandermaaten08a/vandermaaten08a.pdf) ) de donde se deriva nuestra técnica a explicar UMAP. (Es decir, UMAP es un tipo de t-SNE).

# %% [markdown]
# Pero, ¿Por qué otra técnica?

# %% [markdown]
# Cada técnica desarrollada trae mejoras a las anteriores, y un problema que se notó con PCA, era que no brindaba tanta información como se deseaba. Como vimos anteriormente, PCA puede encontrar relaciones lineales entre los datos y explicar, de una manera más global como están los datos, pero si tenemos un conjunto de datos más complicado, puede que PCA no resalte adecuadamente estas relaciones, diferencias o incluso, datos atípicos.

# %% [markdown]
# Aquí mismo, entra a jugar t-SNE. (T-Distributed Stochastic Neighbor Embedding)

# %% [markdown]
# Ahora, supongamos que queremos pasar de un gráfico de dos dimensiones a uno de una sola dimensión. ¡Fácil! Proyectamos todos nuestros datos en un solo eje. ¿Cierto? (Ver imagen 6)

# %% [markdown]
# ![image.png](data:image/png;base64,...) Imagen 6. [Fuente: Edición por el autor](https://www.youtube.com/watch?v=NEaUSP4YerM)

# %% [markdown]
# La respuesta es no. Miremos estos dos diagramas(imagen 7), cada uno con los datos proyectados en cada eje. Se puede notar que se pierden las propiedades de agrupación y variabilidad (distancia entre cada grupo como vimos en PCA).

# %% [markdown]
# ![image.png](data:image/png;base64,...) imagen 7 [Fuente: Editado por el autor](https://www.youtube.com/watch?v=NEaUSP4YerM)

# %% [markdown]
# Entonces, usaremos t-SNE.  Haremos una breve explicación de cómo funciona en dos secciones.

# %% [markdown]
# **Primera sección**
#
# ---

# %% [markdown]
# Para cada uno de nuestros grupos, se mide la distancia entre cada uno de los puntos (datos). Cuando ya se tiene la medición de la distancia de un solo punto hacia todos los demás, se ubican horizontalmente sobre el “piso” de la curva normal (simétrica). y de cada punto hasta que toca la curva se mide la distancia. (Ver imagen 8)

# %% [markdown]
# ![image.png](data:image/png;base64,...) Imagen 8 Fuente:Autor

# %% [markdown]
# **Anotación**: Por las propiedades de la curva normal, los puntos muy distantes a ese punto central significa que tienen entre ellos, bajos niveles de similitud.

# %% [markdown]
# Al ya tener todas las longitudes, se escalan de tal forma que la suma entre ellas es de uno. (¿Por qué uno? Cada grupo puede tener una densidad distinta, entre ellos pueden haber diferencias que en otros grupos es diferente. Por lo tanto, para poder hacer la comparación entre grupos, se hace necesaria esta estandarización).

# %% [markdown]
# Podemos ubicar estas mediciones, también conocidas como puntajes de similitud en una matriz. (Ver imagen 9)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# Imagen 9 Fuente: https://www.youtube.com/watch?v=NEaUSP4YerM editado por Autor

# %% [markdown]
# **Segunda sección**
#
# ---

# %% [markdown]
# Pero, ¿qué hace t-SNE?

# %% [markdown]
# Ubiquemos nuestros datos en un una recta como lo hicimos al comienzo(imagen). Usando t-SNE, se hace lo mismo que vimos en la primera sección pero usando la ***curva t-Student*** en vez de la curva normal. (¿Si te sonaba esa t? Ahí está el porqué de su nombre).

# %% [markdown]
#  *Recordemos: La curva t-student es parecida a la normal, sus colas son mas altas (le da mas probabilidad a las observaciones en los extremos). (Ver imagen 10)*

# %% [markdown]
# ![image.png](data:image/png;base64,...) imagen 10. Fuente: https://tjkyner.medium.com/the-normal-distribution-vs-students-t-distribution-322aa12ffd15

# %% [markdown]
# Efectivamente, nos da una matriz de similitud pero un poco desordenada a comparación de la que se obtuvo con la curva normal. Entonces, t-SNE va moviendo cada punto para lograr obtener la matriz inicial. (imagen 11)

# %% [markdown]
# ![image.png](data:image/png;base64,...) imagen 11 Fuente:https://www.youtube.com/watch?v=NEaUSP4YerM editado por Autor

# %% [markdown]
# **¿y si nos quedamos con t-SNE?**

# %% [markdown]
# Efectivamente, en el 2008 fue publicado el paper que explicaba cómo funcionaba t-SNE. Pero han pasado más de diez años, y sus errores o faltas se fueron visibilizando cada vez mas a medida que la tecnología iba avanzando y se generaban mayores necesidades.
#
#
#
# *   En efecto, a diferencia de PCA, t-SNE no logra preservar la estructura global de los datos. Es decir, analiza las distancias significativas entre grupos (o clusters) (ver imagen 12)
# *   No es un proceso rápido y por ende, consume una alta cantidad de memoria en computadoras

# %% [markdown]
# ![image.png](data:image/png;base64,...)Imagen 12. Fuente: https://towardsdatascience.com/how-exactly-umap-works-13e3040e1668

# %% [markdown]
# # **UMAP**

# %% [markdown]
# ## Ahora si ¿qué significa UMAP?
# Proyeción aproximada de variedades uniformes.
#
# *  **Proyección:** el proceso o técnica de reproducir un objeto espacial sobre un plano, una superficie curva o una línea mediante la proyección de sus puntos. También puede pensar en ello como un mapeo de un objeto desde un espacio de alta dimensión a un espacio de baja dimensión.
# *  **Aproximación:** el algoritmo supone que solo tenemos un conjunto finito de muestras de datos (puntos), no el conjunto completo que forma la variedad. Por lo tanto, necesitamos aproximar la variedad con base en los datos disponibles.
# *  **Variedad**: (Manifold) es un espacio topológico que localmente se parece al espacio euclidiano cerca de cada punto. Las variedades unidimensionales incluyen líneas y círculos, pero no ochos. Las variedades bidimensionales (también conocidas como superficies) incluyen planos, esferas, toros y más.
# *  **Uniforme**: la suposición de uniformidad nos dice que nuestras muestras de datos se distribuyen uniformemente (uniformemente) en la variedad. En el mundo real, sin embargo, este rara vez es el caso. Por lo tanto, esta suposición lleva a la noción de que la distancia varía a lo largo de la variedad. es decir, el espacio mismo se deforma: se estira o se encoge según donde los datos parezcan más dispersos o más densos.

# %% [markdown]
# ## Ventajas
#
#
# *   Es rápido a diferencia de t-SNE, incluso con grandes cantidades de datos
# *   Identifica outliers (Datos atípicos)
# *   Preserva los grupos (Clusters) y su relación entre ellos y con otros grupos.

# %% [markdown]
# ## Ideas principales
# La construcción de representaciones topológicas difusas se puede dividir en dos problemas: aproximar una variedad en la que se supone que se encuentran los datos; y construir una representación de conjunto simplicial difuso de la variedad aproximada.En palabras más simples lo que se desea es
#
# 1.   Dar una aproximación a la agrupación (variedad) en el espacio de alta dimensionalidad del cual son originales los datos.
# 2.   Hacer una representación de esta agrupación en un espacio de menor dimensión.

# %% [markdown]
# ### Aproximación variedad
# Para definir una agrupación se necesita definir el número $k$ de vecinos más cercanos para un punto fijo dado, dónde se incluye el nodo mismo de referencia. Una vez hecho esto, se definen las distancias en el espacio de alta dimensión, lo que finalmente nos ayuda a construir los **pesos de entrada**, los cuales definen una medida de similaridad. Estos pesos son relaciones no simétricas sobre los individuos, generando una matriz de pesos. El último paso es definir las relaciones como **simétricas**. De esta forma, puedo aproximar las variedades. (Ver imagen 13)

# %% [markdown]
# ![image.png](data:image/png;base64,...) Imagen 13[Fuente: Editado por el autor](https://www.youtube.com/watch?v=jth4kEvJ3P8)

# %% [markdown]
# ### Representación de la variedad aproximada
#
# Se tiene un gráfico de inicio (de izquierda a derecha en la imagen) basado en la incrustación espectral, la cual hace que el algoritmo comience desde un mismo punto inicial. Luego, se escoge en cada paso una observación para que se vaya moviendo.
#
# Esto se hace escogiendo dos observaciones del mismo grupo con probabilidad proporcional a los **pesos de entrada** ,y además, se escoge un punto externo a la agrupación, elegida desde la base de que todos tienen la misma probabilidad. La externa me sirve para definir la lejanía y el interno para definir el acercamiento.
#
# En el ejemplo, tengo que acercar $b$ a $a$ y alejarlo de $e$. Para saber en que medida debo realizar estos movimientos, recurro a los **pesos de salida**, los cuales involucro en una función de pérdida que realice un equilibrio entre los pesos. Para la minimización obtamos por la ayuda del *Descenso Estocástico del gradiente*.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Fundamento matemático
# A continuación se presentan los conceptos principales para la realización del algoritmo, para aquellos que no tienen bases de topología o conjuntos borrosos en los cuales se basa UMAP.

# %% [markdown]
# Dadas $N$ observaciones de un conjunto de datos de alta dimensión $\{ \boldsymbol{x}_1, \boldsymbol{x}_2, ..., \boldsymbol{x}_N \}$, la medida de similaridad de la observación $j$  dada la observación $i$ sobre la entrada (alta dimensión), llamados también **pesos de entrada**, se definen como
#
# $$
# v_{j \mid i}=\exp \left[-\left(r_{i j}-\rho_i\right) / \sigma_i\right]
# $$
#
# *  $r_{i j}$ es la distancia entre $\boldsymbol{x}_i$ y $\boldsymbol{x}_j$.
# *  $\rho_i$ es la distancia la observación $\boldsymbol{x}_i$ a su vecino más cercano.
# *  $\sigma_i$ es una constante determinada para cumplir $\sum_j v_{j \mid i}=\log _2 k$, donde $k$ es el número de vecinos más cercanos.
# *  $v_{j \mid i} \in (0,1]$. Note que $v_{j \mid i}=1$ cuando $\boldsymbol{x}_j$ es el vecino más cercano a $\boldsymbol{x}_i$ y disminuye a medida que la observación se encuentre más lejos de $\boldsymbol{x}_i$.
#
# La notación $v_{j \mid i}$ en lugar de $v_{ij}$ se usa para representar la relación *asimétrica*, es decir, $v_{j \mid i} \neq v_{i \mid j}$. Sin embargo, es conveniente simetrizar esta similiraidad mediante
# $$
# v_{i j}=\left(v_{j \mid i}+v_{i \mid j}\right)-v_{j \mid i} v_{i \mid j}
# $$
# la cual lleva a cabo efectivamente una *unión de conjuntos difusos*.

# %% [markdown]
# En el espacio de salida de las coordenadas incrustadas $\{ \boldsymbol{y}_1, \boldsymbol{y}_2, ..., \boldsymbol{y}_N \}$, la similitud entre los puntos $\boldsymbol{y}_i$ e $\boldsymbol{y}_j$, tambien conocidos como **pesos de salida**, están dados por
#
# $$
# w_{i j}=1 /\left(1+α d_{i j}^{2 β}\right)
# $$
#
# *  $d_{i j}$ es la distancia euclideana entre $\boldsymbol{y}_i$ e $\boldsymbol{y}_j$.
# *  $α$, $β$ son contantes determinadas por un ajuste de mínimos cuadrados no lineal basado en los parámetros `min_dist` y `spread` que controlan la rigidez de la función de agrupamiento.
# * $w_{ij} \in (0,1]$. Note que $w_{ij} =1$ cuando $\boldsymbol{y}_j$ tiene las mismas coordenadas de $\boldsymbol{y}_i$ y disminuye a medida que la observación se encuentre más lejos de $\boldsymbol{y}_i$.
#
# Los valores predeterminados de UMAP usan `min_dist = 0,1` y `spread = 1`, lo que da como resultado $α=1,577$ y $β=0,8951$. Si $α=β=1$ se obtienen los pesos empleados por t-SNE.

# %% [markdown]
# La **función de costo** es la entropía cruzada de dos conjuntos borrosos, que se pueden representar como matrices de peso simétricas:
#
# $$
# C_{U M A P}=\sum_{i, j}\left[v_{i j} \log \left(\frac{v_{i j}}{w_{i j}}\right)+\left(1-v_{i j}\right) \log \left(\frac{1-v_{i j}}{1-w_{i j}}\right)\right]
# $$

# %% [markdown]
# # Ejemplo

# %%
# Data manipulation
import pandas as pd # for data manipulation
import numpy as np # for data manipulation

# Visualization
import plotly.express as px # for data visualization
import matplotlib.pyplot as plt # for showing handwritten digits

# Sklearn
from sklearn.datasets import load_digits # para datos MNIST 
from sklearn.model_selection import train_test_split # splitting data en muestras de entrenamiento y test

# UMAP 
#!pip install umap-learn # instalacion
from umap import UMAP

# %%
# Load digits data 
digits = load_digits()

# Load arrays containing digit data (64 pixels per image) and their true labels
X, y = load_digits(return_X_y=True)

# Some stats
print('Shape of digit images: ', digits.images.shape)
print('Shape of X (main data): ', X.shape)
print('Shape of y (true labels): ', y.shape)

# Display images of the first 10 digits
fig, axs = plt.subplots(2, 5, sharey=False, tight_layout=True, figsize=(12,6), facecolor='white')
n=0
plt.gray() 
for i in range(0,2):
    for j in range(0,5):
        axs[i,j].matshow(digits.images[n])
        axs[i,j].set(title=y[n])
        n=n+1
plt.show()
# Out:
# Shape of digit images:  (1797, 8, 8)
# Shape of X (main data):  (1797, 64)
# Shape of y (true labels):  (1797,)

# %%
def chart(X, y):
    #--------------------------------------------------------------------------#
    # This section is not mandatory as its purpose is to sort the data by label 
    # so, we can maintain consistent colors for digits across multiple graphs
    
    # Concatenate X and y arrays
    arr_concat=np.concatenate((X, y.reshape(y.shape[0],1)), axis=1)
    # Create a Pandas dataframe using the above array
    df=pd.DataFrame(arr_concat, columns=['x', 'y', 'z', 'label'])
    # Convert label data type from float to integer
    df['label'] = df['label'].astype(int)
    # Finally, sort the dataframe by label
    df.sort_values(by='label', axis=0, ascending=True, inplace=True)
    #--------------------------------------------------------------------------#
    
    # Create a 3D graph
    fig = px.scatter_3d(df, x='x', y='y', z='z', color=df['label'].astype(str), height=900, width=950)

    # Update chart looks
    fig.update_layout(title_text='UMAP',
                      showlegend=True,
                      legend=dict(orientation="h", yanchor="top", y=0, xanchor="center", x=0.5),
                      scene_camera=dict(up=dict(x=0, y=0, z=1), 
                                            center=dict(x=0, y=0, z=-0.1),
                                            eye=dict(x=1.5, y=-1.4, z=0.5)),
                                            margin=dict(l=0, r=0, b=0, t=0),
                      scene = dict(xaxis=dict(backgroundcolor='white',
                                              color='black',
                                              gridcolor='#f0f0f0',
                                              title_font=dict(size=10),
                                              tickfont=dict(size=10),
                                             ),
                                   yaxis=dict(backgroundcolor='white',
                                              color='black',
                                              gridcolor='#f0f0f0',
                                              title_font=dict(size=10),
                                              tickfont=dict(size=10),
                                              ),
                                   zaxis=dict(backgroundcolor='lightgrey',
                                              color='black', 
                                              gridcolor='#f0f0f0',
                                              title_font=dict(size=10),
                                              tickfont=dict(size=10),
                                             )))
    # Update marker size
    fig.update_traces(marker=dict(size=3, line=dict(color='black', width=0.1)))
    
    fig.show()

# %%
# Configure UMAP hyperparameters
reducer = UMAP(n_neighbors=100, # default 15, The size of local neighborhood (in terms of number of neighboring sample points) used for manifold approximation.
               n_components=3, # default 2, The dimension of the space to embed into.
               metric='euclidean', # default 'euclidean', The metric to use to compute distances in high dimensional space.
               n_epochs=1000, # default None, The number of training epochs to be used in optimizing the low dimensional embedding. Larger values result in more accurate embeddings. 
               learning_rate=1.0, # default 1.0, The initial learning rate for the embedding optimization.
               init='spectral', # default 'spectral', How to initialize the low dimensional embedding. Options are: {'spectral', 'random', A numpy array of initial embedding positions}.
               min_dist=0.1, # default 0.1, The effective minimum distance between embedded points.
               spread=1.0, # default 1.0, The effective scale of embedded points. In combination with ``min_dist`` this determines how clustered/clumped the embedded points are.
               low_memory=False, # default False, For some datasets the nearest neighbor computation can consume a lot of memory. If you find that UMAP is failing due to memory constraints consider setting this option to True.
               set_op_mix_ratio=1.0, # default 1.0, The value of this parameter should be between 0.0 and 1.0; a value of 1.0 will use a pure fuzzy union, while 0.0 will use a pure fuzzy intersection.
               local_connectivity=1, # default 1, The local connectivity required -- i.e. the number of nearest neighbors that should be assumed to be connected at a local level.
               repulsion_strength=1.0, # default 1.0, Weighting applied to negative samples in low dimensional embedding optimization.
               negative_sample_rate=5, # default 5, Increasing this value will result in greater repulsive force being applied, greater optimization cost, but slightly more accuracy.
               transform_queue_size=4.0, # default 4.0, Larger values will result in slower performance but more accurate nearest neighbor evaluation.
               a=None, # default None, More specific parameters controlling the embedding. If None these values are set automatically as determined by ``min_dist`` and ``spread``.
               b=None, # default None, More specific parameters controlling the embedding. If None these values are set automatically as determined by ``min_dist`` and ``spread``.
               random_state=42, # default: None, If int, random_state is the seed used by the random number generator;
               metric_kwds=None, # default None) Arguments to pass on to the metric, such as the ``p`` value for Minkowski distance.
               angular_rp_forest=False, # default False, Whether to use an angular random projection forest to initialise the approximate nearest neighbor search.
               target_n_neighbors=-1, # default -1, The number of nearest neighbors to use to construct the target simplcial set. If set to -1 use the ``n_neighbors`` value.
               #target_metric='categorical', # default 'categorical', The metric used to measure distance for a target array is using supervised dimension reduction. By default this is 'categorical' which will measure distance in terms of whether categories match or are different. 
               #target_metric_kwds=None, # dict, default None, Keyword argument to pass to the target metric when performing supervised dimension reduction. If None then no arguments are passed on.
               #target_weight=0.5, # default 0.5, weighting factor between data topology and target topology.
               transform_seed=42, # default 42, Random seed used for the stochastic aspects of the transform operation.
               verbose=False, # default False, Controls verbosity of logging.
               unique=False, # default False, Controls if the rows of your data should be uniqued before being embedded. 
              )

# Fit and transform the data
X_trans = reducer.fit_transform(X)

# Check the shape of the new data
print('Shape of X_trans: ', X_trans.shape)
# Out:
# Shape of X_trans:  (1797, 3)

# %%
chart(X_trans, y)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Ejercicio para el lector

# %% [markdown]
# ![image.png](data:image/png;base64,...)Imagen 14[Fuente: How to Use UMAP. Penguin Datet](https://umap-learn.readthedocs.io/en/latest/basic_usage.html#penguin-data)

# %% [markdown]
# Vamos a mirar un pequeño ejemplo que puedes ayudarnos a terminar, pero podría ayudarte a clarificar y poner en práctica lo que sabes de programación y entender como UMAP funciona.

# %% [markdown]
# Puedes obtener la base de datos de la siguiente manera:

# %%
import numpy as np
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
penguins = pd.read_csv("https://raw.githubusercontent.com/allisonhorst/palmerpenguins/c19a904462482430170bfe2c718775ddb7dbb885/inst/extdata/penguins.csv")
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007

# %% [markdown]
# Podemos ver que para unos pinguinos se hicieron las obserevaciones de su especie, isla, largo del pico, ancho del pico, entre otras.

# %% [markdown]
# ![image.png](data:image/png;base64,...)[Fuente:PinguinDataset](https://umap-learn.readthedocs.io/en/latest/basic_usage.html)

# %% [markdown]
# **NOTA** Es importante mencionar que los valores NaN van a ser omitidos por practicidad, pero sabemos que en el mundo real, pueden presentarse y no deberian ser omitidos.

# %%
penguins = penguins.dropna()
penguins.species.value_counts()
# Out:
# Adelie       146
# Gentoo       119
# Chinstrap     68
# Name: species, dtype: int64

# %% [markdown]
# Si recordamos cómo funciona PCA, sabemos que podemos hacer el gráfico de dispersión para cada una de las variables.

# %%
sns.pairplot(penguins.drop("year", axis=1), hue='species');

# %% [markdown]
# **La pregunta es, ¿en qué nos ayudaria UMAP?**

# %% [markdown]
# Para este ejercicio, intenta desarollar el gráfico para dos dimensiones de los datos sobre las distintas especies de pinguinos. (No te preocupes, te damos la respuesta. Pero intenta sacar al máximo tus habilidades y conocimiento adquirido). Luego, puedes comparar con otra forma de hacerlo.

# %% [markdown]
# Te damos una idea de por dónde comenzar

# %%
from umap import UMAP

# %%
penguin_data = penguins[
    [
        "bill_length_mm",
        "bill_depth_mm",
        "flipper_length_mm",
        "body_mass_g",
    ]
].values
scaled_penguin_data = StandardScaler().fit_transform(penguin_data)

# %%
#@title
embedding = reducer.fit_transform(scaled_penguin_data)
embedding.shape
# Out:
# (333, 3)

# %%
#@title
plt.scatter(
    embedding[:, 0],
    embedding[:, 1],
    c=[sns.color_palette()[x] for x in penguins.species.map({"Adelie":0, "Chinstrap":1, "Gentoo":2})])
plt.gca().set_aspect('equal', 'datalim')
plt.title('Proyección UMAP para la base de datos de pinguinos', fontsize=24);

# %% [markdown]
# Tomado de: [How to use UMAP. Penguin Dataset](https://umap-learn.readthedocs.io/en/latest/basic_usage.html)
